# %% [markdown]
# W2A1

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# W2A2

# %%
a = input('nhap ten nguoi dung: ')
print('Xin Chao', a , 'Chuc ban ngay moi tot lanh')
# Out:
# Xin Chao long Chuc ban ngay moi tot lanh

# %% [markdown]
# W2A3

# %%
def g(a,b):
    if b == 0:
        print('lỗi không thể chia cho không:')
        return
    tong = a + b
    hieu = a - b
    tich = a*b
    chianguyen = a//b
    chiadu = a%b
    chia = a/b
    
    print(tong)
    print(hieu)
    print(tich)
    print(chianguyen)
    print(chiadu)
    print(f"{chia:.2f}")
a = int(input())
b = int(input())    
g(a,b)
# Out:
# 7
# -1
# 12
# 0
# 3
# 0.75

# %% [markdown]
# W2A4

# %%
def g(a1,b1,c1,a2,b2,a3):
        tb = ((a1+b1+c1)+(a2+b2)*2+a3*3)/10
        print(f"{tb:.1f}")
a1,b1,c1,a2,b2,a3 = map(int,input().split())
g(a1,b1,c1,a2,b2,a3)
# Out:
# 5.2

# %% [markdown]
# W2A5

# %%
def g(a,b):
    mu = a**b
    return mu
a,b = map(int,input().split())
ket = g(a,b)
print(ket)
# Out:
# 1024

# %% [markdown]
# W2A6

# %%
a = input()
print(ord(a))
print(chr(ord(a)-32))
# Out:
# 97
# A

# %% [markdown]
# W2A7

# %%
A = ((13**2)*3)+5
B = 13**2*3 +5
print(A)
print(B)
# Out:
# 512
# 512

# %%
c = float(input())
f = (9/5)*c + 32
print(f"{f:.2f}")
# Out:
# 38.12

# %% [markdown]
# W2A9

# %%
x = float(input())
gia = x*1.4+10
print (gia)
# Out:
# 38.0

# %% [markdown]
# W2A10

# %%
a,b,c = map(str,input().split())
print("Hi",c+",",b,"and",a+".")
# Out:
# Hi Helen, ALice and Bob.

# %% [markdown]
# W2A11

# %%
a,b = map(int,input().split())
print(a*3600 + b*60)
# Out:
# 3660

# %% [markdown]
# W2A12

# %%
n = int(input())
print(n*n*6)
# Out:
# 54

# %% [markdown]
# W2A13

# %%
a,b= map(int,input().split())
print((a*b)%10)

# %% [markdown]
# W2A14

# %%
a,b = map(int,input().split())
a = a + b 
b = a - b 
a = a - b
print(a,b)

# %% [markdown]
# W2A15

# %%
n = int(input())
print(6*n*(n + 1) + 1)

# %% [markdown]
# W2A16

# %%
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %% [markdown]
# W2A17

# %%
print("*\n**\n***")
# Out:
# *
# **
# ***

# %% [markdown]
# W2A18

# %%
print("### # #   ### ###\n #  #  #   #   #\n #  #   #  #   #\n #  #  #   #   #\n #  # #    #   #")
# Out:
# ### # #   ### ###
#  #  #  #   #   #
#  #  #   #  #   #
#  #  #  #   #   #
#  #  # #    #   #

# %% [markdown]
# W2A19

# %%
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %% [markdown]
# W2A20

# %%
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %% [markdown]
# W2A21

# %%
for i in range (0,10):
    print("Hello, World")
# Out:
# Hello, World
# Hello, World
# Hello, World
# Hello, World
# Hello, World
# Hello, World
# Hello, World
# Hello, World
# Hello, World
# Hello, World
