# %% [markdown]
# Bài 1

# %%
a,b= map(int,input().split())
print(a*b,(a+b)*2)

# %% [markdown]
# Bài 2

# %%
a=int(input())
print(3.14*a*a,2*3.14*a)

# %% [markdown]
# Bài 3

# %%
import math
a,b,c=map(int,input().split())
if a+b>c and a+c>b and b+c>a:
    if a == b == c:
        print("Tam giac deu:")
    elif a == b or a==c or b==c:
        if a**2+b**2==c**2 :
            print("Tam giac vuong can:")
        else:
            print("Tam giac can:")
    elif a**2+b**2==c**2:
        print("Tam giac vuong:")
else:
    print("Khong la ba canh cua mot tam giac")
p=(a+b+c)/2
print(math.sqrt(p*(p-a)*(p-b)*(p-c)),2*p)

# %% [markdown]
# Bài 4

# %%
a,b=map(float,input().split())
if(a and b != 0):
    print(f"{(-b/a):.2f}")
elif(a==0):
    print("Vô nghiệm")
elif(a==0 and b ==0):
    print("Vô số nghiệm")

# %% [markdown]
# Bài 5

# %%
import math
a,b,c = map(int,input().split())
delta = b**2 -4**a**c
if ((delta < 0) and (a!=0)) or (a==0 and b==0 and c!=0) :
    print("Vo nghiem")
elif a==0 and b==0 and c==0:
    print("Vo so nghiem")
elif delta ==0:
    print("2 nghiem kep la:",-b/a)
elif delta > 0:
    nghiem_1=(-b+ math.sqrt(delta)/(2**a))
    nghiem_2=(-b- math.sqrt(delta)/(2**a))
    print("2 ngiem la:",nghiem_1,nghiem_2)

# %% [markdown]
# Bài 6
